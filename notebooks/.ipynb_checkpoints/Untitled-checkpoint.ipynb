# %%
import pandas as pd
import numpy as np


df = pd.read_csv('data/data.csv')
df = df.rename(columns={
    'Dish Name': 'Food',
    'Calories (kcal)': 'Calories',
    'Protein (g)': 'Protein',
    'Carbohydrates (g)': 'Carbs',
    'Fats (g)': 'Fat',
    'Meal Category': 'Meal',
    'Diet Type': 'Type',
    'Frequency': 'Category'
})

# %%
def calculate_bmi(weight_kg, height_m):
    bmi = weight_kg / ((height_m/100) ** 2)
    return bmi

# %%
def calculate_calories(weight, height, age,gender):
    if gender == "male":
        return 10*weight + 6.25*height - 5*age + 5
    else:
        return 10*weight + 6.25*height - 5*age - 161

# %%
def calculate_protein(weight, goal):
    if goal == "muscle":
        return weight * 2.0
    elif goal == "fat_loss":
        return weight * 1.6
    else:
        return weight * 1.2

# %%
df.describe()
# Out:
#           Calories        Carbs      Protein          Fat  Free Sugar (g)  \
# count  1014.000000  1014.000000  1014.000000  1014.000000     1014.000000
# mean    233.735897    18.354004     4.753008    16.267584        8.824832
# std     187.599467    16.745936     3.442746    20.452322       12.378324
# min       6.610000     0.000000     0.000000     0.000000        0.000000
# 25%     101.180000     5.582500     2.100000     4.030000        1.152500
# 50%     174.920000    11.925000     3.990000     9.095000        2.780000
# 75%     315.845000    26.870000     6.602500    17.085000       11.822500
# max     839.330000    86.530000    21.550000    90.450000       85.570000
#
#          Fibre (g)   Sodium (mg)  Calcium (mg)    Iron (mg)  Vitamin C (mg)  \
# count  1014.000000   1014.000000   1014.000000  1014.000000      932.000000
# mean      1.962485    481.076755     59.877091     1.136953       14.985172
# std       2.771622   1750.646423     67.441463     1.520863       26.619886
# min       0.000000      0.000000      0.000000     0.000000        0.000000
# 25%       0.590000     41.910000     18.237500     0.460000        1.257500
# 50%       1.325000    101.290000     40.680000     0.830000        5.400000
# 75%       2.347500    196.605000     79.385000     1.290000       18.222500
# max      35.710000  14174.590000    631.820000    20.570000      382.640000
#
#        Folate (µg)  Serving Size
# count   932.000000   1014.000000
# mean     41.920000      1.357002
# std      54.147515      0.677348
# min       0.000000      1.000000
# 25%      11.955000      1.000000
# 50%      24.770000      1.000000
# 75%      49.100000      2.000000
# max     550.520000      4.000000

# %%
df.isna().sum()
# Out:
# Food               0
# Calories           0
# Carbs              0
# Protein            0
# Fat                0
# Free Sugar (g)     0
# Fibre (g)          0
# Sodium (mg)        0
# Calcium (mg)       0
# Iron (mg)          0
# Vitamin C (mg)    82
# Folate (µg)       82
# Meal               0
# Type               0
# Category           0
# Serving Size       0
# dtype: int64

# %%
from sklearn.cluster import KMeans


    
    # Select features
X = df[['Calories', 'Protein', 'Carbs', 'Fat']]
    
    # Train model
kmeans = KMeans(n_clusters=4, random_state=42)
    
    # Fit and predict
df['Cluster'] = kmeans.fit_predict(X)
    
print(df.groupby('Cluster')[['Calories','Protein','Carbs','Fat']].mean())
# Out:
#            Calories   Protein      Carbs        Fat
# Cluster
# 0        217.624203  5.875627  24.714780  10.896169
# 1        673.624500  2.546400   7.696300  70.314900
# 2         90.355130  4.033826   9.411717   4.983130
# 3        401.781447  6.138616  39.126289  24.888239
# C:\Users\prady\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
print(df)
# Out:
#                                                    Food  Calories  Carbs  \
# 0                                  Hot tea (Garam Chai)     16.14   2.58
# 1                                        Instant coffee     23.16   3.65
# 2                                        Espreso coffee     51.54   6.62
# 3                                              Iced tea     10.34   2.70
# 4                           Raw mango drink (Aam panna)     35.92   9.05
# ...                                                 ...       ...    ...
# 1009  Sweet and sour tomato pickle (Khatta meetha ta...     60.88   6.55
# 1010  Jhatpat achar with carrot (Jhatpat achaar gaja...     91.21   6.32
# 1011                Tomato chutney (Tamatar ki chutney)    176.07  31.85
# 1012                                     Tomato ketchup     33.07   6.48
# 1013                Bengal 5 Spice Blend (Panch Phoran)    289.79  20.00
#
#       Protein    Fat  Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  \
# 0        0.39   0.53            2.58       0.00         3.12         14.20
# 1        0.64   0.75            3.62       0.00         4.92         20.87
# 2        1.75   2.14            6.53       0.00        13.98         58.10
# 3        0.03   0.01            2.70       0.00         0.23          1.18
# 4        0.16   0.03            7.49       0.61        79.82          7.08
# ...       ...    ...             ...        ...          ...           ...
# 1009     1.26   3.24            4.31       2.20      1281.94         15.18
# 1010     1.98   6.55            3.04       5.08      2067.33         54.31
# 1011     0.97   6.01           30.02       1.49       823.65         25.34
# 1012     0.91   0.30            4.68       1.90       177.97         15.33
# 1013    18.26  22.16            1.40      18.40        51.43        523.00
#
#       Iron (mg)  Vitamin C (mg)  Folate (µg)       Meal Type    Category  \
# 0          0.02            0.50         1.80  Breakfast  Veg      Staple
# 1          0.06            1.51         5.60  Breakfast  Veg      Staple
# 2          0.15            1.51         5.53  Breakfast  Veg      Staple
# 3          0.02            5.95         1.28  Breakfast  Veg      Staple
# 4          0.14           45.30        14.05    Anytime  Veg  Non-Staple
# ...         ...             ...          ...        ...  ...         ...
# 1009       0.54             NaN          NaN    Anytime  Veg  Non-Staple
# 1010       2.32             NaN          NaN    Anytime  Veg  Non-Staple
# 1011       0.96             NaN          NaN    Anytime  Veg  Non-Staple
# 1012       0.36             NaN          NaN    Anytime  Veg  Non-Staple
# 1013      13.37             NaN          NaN    Anytime  Veg  Non-Staple
#
#       Serving Size  Cluster
# 0                1        2
# 1                1        2
# 2                1        2
# 3                1        2
# 4                1        2
# ...            ...      ...
# 1009             1        2
# 1010             1        2
# 1011             1        0
# 1012             1        2
# 1013             1        0
#
# [1014 rows x 17 columns]
